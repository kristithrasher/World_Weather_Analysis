# %%
# Deliverable 1 Retrieve Weather Data
#and . In addition to the city weather data you gathered 
#in this module, use your API skills to retrieve the current weather description for each city. 
#Then, create a new DataFrame containing the updated weather data.
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the API key.
from config import weather_api_key

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Generate a set of 2,000 random latitudes and longitudes, 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
#print(coordinates)

# %%
# retrieve the nearest city, 
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Next, we need to iterate through our list of cities
# and begin building the URL for each city, 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #print(requests.get(city_url).json())

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
      # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
       
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : weather_description
                         })
                         

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | lompoc
# Processing Record 4 of Set 1 | alcaniz
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | skhisma
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | swift current
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | santa cruz
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | nerchinskiy zavod
# Processing Record 15 of Set 1 | kuvandyk
# Processing Record 16 of Set 1 | makakilo city
# Processing Record 17 of Set 1 | udachnyy
# Processing Record 18 of Set 1 | akdepe
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | kabompo
# Processing Record 21 of Set 1 | vestmannaeyjar
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | marzuq
# Processing Record 25 of Set 1 | keningau
# Processing Record 26 of Set 1 | zhitikara
# City not found. Skipping...
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | solano
# Processing Record 29 of Set 1 | sakaiminato
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | chenzhou
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | itarema
# Processing Record 35 of Set 1 | verkh-tula
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | houma
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | aktash
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | dikson
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | grindavik
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | guerrero negro
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | kamien pomorski
# Processing Record 48 of Set 1 | padang
# Processing Record 49 of Set 1 | rikitea
# Processing Record 50 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | victoria
# Processing Record 3 of Set 2 | dunedin
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | sioux lookout
# Processing Record 6 of Set 2 | skibbereen
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | saldanha
# Processing Record 10 of Set 2 | champerico
# Processing Record 11 of Set 2 | ponta do sol
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | yar-sale
# Processing Record 14 of Set 2 | srednekolymsk
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | uddevalla
# Processing Record 17 of Set 2 | whitehorse
# Processing Record 18 of Set 2 | asau
# Processing Record 19 of Set 2 | barcelos
# Processing Record 20 of Set 2 | fairbanks
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | mwinilunga
# Processing Record 23 of Set 2 | taguatinga
# Processing Record 24 of Set 2 | husavik
# Processing Record 25 of Set 2 | mataura
# Processing Record 26 of Set 2 | piet retief
# Processing Record 27 of Set 2 | dvinskoy
# Processing Record 28 of Set 2 | meulaboh
# Processing Record 29 of Set 2 | shawnee
# Processing Record 30 of Set 2 | xambioa
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | pevek
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | namibe
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | flinders
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | teya
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | jamestown
# Processing Record 44 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | maumere
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | sinnamary
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | orlik
# Processing Record 3 of Set 3 | berbera
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | tuktoyaktuk
# Processing Record 6 of Set 3 | hofn
# Processing Record 7 of Set 3 | richards bay
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | mayumba
# Processing Record 11 of Set 3 | port hardy
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | tres arroyos
# Processing Record 14 of Set 3 | damaturu
# Processing Record 15 of Set 3 | solnechnyy
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | toora-khem
# Processing Record 18 of Set 3 | klaksvik
# Processing Record 19 of Set 3 | beloha
# Processing Record 20 of Set 3 | huarmey
# Processing Record 21 of Set 3 | gobabis
# Processing Record 22 of Set 3 | saint-philippe
# Processing Record 23 of Set 3 | coahuayana
# Processing Record 24 of Set 3 | sadove
# Processing Record 25 of Set 3 | talnakh
# Processing Record 26 of Set 3 | zomba
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | hoquiam
# Processing Record 29 of Set 3 | aketi
# Processing Record 30 of Set 3 | santa marta
# Processing Record 31 of Set 3 | puerto maldonado
# Processing Record 32 of Set 3 | fukue
# Processing Record 33 of Set 3 | masaka
# Processing Record 34 of Set 3 | kralendijk
# Processing Record 35 of Set 3 | oriximina
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 3 | naze
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | nhulunbuy
# Processing Record 42 of Set 3 | kuching
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | brae
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | komsomolskiy
# Processing Record 47 of Set 3 | salinopolis
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | vanimo
# Processing Record 50 of Set 3 | egvekinot
# Processing Record 1 of Set 4 | vila franca do campo
# Processing Record 2 of Set 4 | cidreira
# Processing Record 3 of Set 4 | touros
# Processing Record 4 of Set 4 | vao
# Processing Record 5 of Set 4 | mathbaria
# Processing Record 6 of Set 4 | arona
# Processing Record 7 of Set 4 | lago da pedra
# Processing Record 8 of Set 4 | port blair
# Processing Record 9 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 4 | muros
# Processing Record 11 of Set 4 | ayagoz
# Processing Record 12 of Set 4 | tongren
# Processing Record 13 of Set 4 | deputatskiy
# Processing Record 14 of Set 4 | dukat
# Processing Record 15 of Set 4 | remontnoye
# Processing Record 16 of Set 4 | araouane
# Processing Record 17 of Set 4 | berlevag
# Processing Record 18 of Set 4 | antofagasta
# Processing Record 19 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | westport
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | ivrea
# Processing Record 24 of Set 4 | megalopoli
# Processing Record 25 of Set 4 | baykalsk
# Processing Record 26 of Set 4 | yellowknife
# Processing Record 27 of Set 4 | turukhansk
# Processing Record 28 of Set 4 | mattru
# Processing Record 29 of Set 4 | port-gentil
# Processing Record 30 of Set 4 | ahipara
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | evensk
# Processing Record 33 of Set 4 | ancud
# Processing Record 34 of Set 4 | neiafu
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | sao jose da coroa grande
# Processing Record 37 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 39 of Set 4 | alugan
# Processing Record 40 of Set 4 | kidal
# Processing Record 41 of Set 4 | kangaatsiaq
# Processing Record 42 of Set 4 | airai
# Processing Record 43 of Set 4 | vardo
# Processing Record 44 of Set 4 | morant bay
# Processing Record 45 of Set 4 | thinadhoo
# Processing Record 46 of Set 4 | aklavik
# Processing Record 47 of Set 4 | orumiyeh
# Processing Record 48 of Set 4 | kungurtug
# Processing Record 49 of Set 4 | puri
# Processing Record 50 of Set 4 | horsham
# Processing Record 1 of Set 5 | rafaela
# Processing Record 2 of Set 5 | arman
# Processing Record 3 of Set 5 | necochea
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | sampang
# Processing Record 6 of Set 5 | mkushi
# Processing Record 7 of Set 5 | banda aceh
# Processing Record 8 of Set 5 | bilma
# Processing Record 9 of Set 5 | xucheng
# Processing Record 10 of Set 5 | sosnovo-ozerskoye
# Processing Record 11 of Set 5 | quatre cocos
# Processing Record 12 of Set 5 | mackay
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | tazovskiy
# Processing Record 15 of Set 5 | thompson
# Processing Record 16 of Set 5 | ramnagar
# Processing Record 17 of Set 5 | acapulco
# Processing Record 18 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 5 | torbay
# Processing Record 20 of Set 5 | chicama
# Processing Record 21 of Set 5 | cap malheureux
# Processing Record 22 of Set 5 | sfantu gheorghe
# Processing Record 23 of Set 5 | la ronge
# Processing Record 24 of Set 5 | lamu
# Processing Record 25 of Set 5 | sisimiut
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | gelemso
# Processing Record 28 of Set 5 | bethel
# Processing Record 29 of Set 5 | boa vista
# Processing Record 30 of Set 5 | liverpool
# Processing Record 31 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 5 | sulangan
# Processing Record 33 of Set 5 | clyde river
# Processing Record 34 of Set 5 | taoudenni
# Processing Record 35 of Set 5 | farafangana
# Processing Record 36 of Set 5 | turangi
# Processing Record 37 of Set 5 | alofi
# Processing Record 38 of Set 5 | berezovyy
# Processing Record 39 of Set 5 | minab
# Processing Record 40 of Set 5 | sumenep
# Processing Record 41 of Set 5 | tanete
# Processing Record 42 of Set 5 | beringovskiy
# Processing Record 43 of Set 5 | semnan
# Processing Record 44 of Set 5 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 5 | eyrarbakki
# Processing Record 46 of Set 5 | nikolskoye
# Processing Record 47 of Set 5 | tairua
# Processing Record 48 of Set 5 | iqaluit
# Processing Record 49 of Set 5 | cherskiy
# Processing Record 50 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 6 | camopi
# Processing Record 2 of Set 6 | skjervoy
# Processing Record 3 of Set 6 | emerald
# Processing Record 4 of Set 6 | savinka
# Processing Record 5 of Set 6 | birao
# Processing Record 6 of Set 6 | alto araguaia
# Processing Record 7 of Set 6 | cockburn town
# Processing Record 8 of Set 6 | xiazhen
# Processing Record 9 of Set 6 | seoul
# Processing Record 10 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 6 | boatlaname
# City not found. Skipping...
# Processing Record 12 of Set 6 | kamaishi
# Processing Record 13 of Set 6 | alta
# Processing Record 14 of Set 6 | port-cartier
# Processing Record 15 of Set 6 | primorsk
# Processing Record 16 of Set 6 | northam
# Processing Record 17 of Set 6 | vostok
# Processing Record 18 of Set 6 | crossville
# Processing Record 19 of Set 6 | kysyl-syr
# Processing Record 20 of Set 6 | nkoteng
# Processing Record 21 of Set 6 | ambikapur
# Processing Record 22 of Set 6 | avera
# Processing Record 23 of Set 6 | caravelas
# Processing Record 24 of Set 6 | portalegre
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | buta
# Processing Record 27 of Set 6 | smirnykh
# Processing Record 28 of Set 6 | myaundzha
# Processing Record 29 of Set 6 | bairiki
# Processing Record 30 of Set 6 | coihaique
# Processing Record 31 of Set 6 | tiarei
# Processing Record 32 of Set 6 | olesno
# Processing Record 33 of Set 6 | bilibino
# Processing Record 34 of Set 6 | peterhead
# Processing Record 35 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 6 | khuzhir
# Processing Record 37 of Set 6 | kastamonu
# Processing Record 38 of Set 6 | anantapur
# Processing Record 39 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 40 of Set 6 | half moon bay
# Processing Record 41 of Set 6 | palembang
# Processing Record 42 of Set 6 | tura
# Processing Record 43 of Set 6 | ambilobe
# Processing Record 44 of Set 6 | biltine
# Processing Record 45 of Set 6 | harper
# Processing Record 46 of Set 6 | bonito
# Processing Record 47 of Set 6 | pag
# Processing Record 48 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 6 | tari
# Processing Record 50 of Set 6 | shieli
# Processing Record 1 of Set 7 | gizo
# Processing Record 2 of Set 7 | novikovo
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | penzance
# Processing Record 5 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 7 | cayenne
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | sakakah
# Processing Record 10 of Set 7 | millbrook
# Processing Record 11 of Set 7 | fare
# Processing Record 12 of Set 7 | chunoyar
# Processing Record 13 of Set 7 | burayevo
# Processing Record 14 of Set 7 | cascais
# Processing Record 15 of Set 7 | sao felix do xingu
# Processing Record 16 of Set 7 | torrijos
# Processing Record 17 of Set 7 | yulara
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | luwero
# Processing Record 20 of Set 7 | shangrao
# Processing Record 21 of Set 7 | grafton
# Processing Record 22 of Set 7 | kruisfontein
# Processing Record 23 of Set 7 | port lincoln
# Processing Record 24 of Set 7 | luancheng
# Processing Record 25 of Set 7 | aberdeen
# Processing Record 26 of Set 7 | port hedland
# Processing Record 27 of Set 7 | omboue
# Processing Record 28 of Set 7 | ulladulla
# Processing Record 29 of Set 7 | sept-iles
# Processing Record 30 of Set 7 | swellendam
# Processing Record 31 of Set 7 | san patricio
# Processing Record 32 of Set 7 | provideniya
# Processing Record 33 of Set 7 | gravelbourg
# Processing Record 34 of Set 7 | mana
# Processing Record 35 of Set 7 | terrace bay
# Processing Record 36 of Set 7 | aparecida do taboado
# Processing Record 37 of Set 7 | fort smith
# Processing Record 38 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 7 | krasnoselkup
# Processing Record 40 of Set 7 | sokoni
# Processing Record 41 of Set 7 | waipawa
# Processing Record 42 of Set 7 | murgab
# Processing Record 43 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 44 of Set 7 | port macquarie
# Processing Record 45 of Set 7 | hobyo
# Processing Record 46 of Set 7 | progreso
# Processing Record 47 of Set 7 | viedma
# Processing Record 48 of Set 7 | alice springs
# Processing Record 49 of Set 7 | longyearbyen
# Processing Record 50 of Set 7 | carbonia
# Processing Record 1 of Set 8 | teguise
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | san nicolas
# Processing Record 4 of Set 8 | nelson bay
# Processing Record 5 of Set 8 | sur
# Processing Record 6 of Set 8 | buala
# Processing Record 7 of Set 8 | tolaga bay
# Processing Record 8 of Set 8 | erenhot
# Processing Record 9 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 8 | oropoli
# Processing Record 11 of Set 8 | maragogi
# Processing Record 12 of Set 8 | sibolga
# Processing Record 13 of Set 8 | zeya
# Processing Record 14 of Set 8 | asmara
# Processing Record 15 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 16 of Set 8 | zhuravka
# Processing Record 17 of Set 8 | mirabad
# Processing Record 18 of Set 8 | porto velho
# Processing Record 19 of Set 8 | safidon
# Processing Record 20 of Set 8 | portland
# Processing Record 21 of Set 8 | ilulissat
# Processing Record 22 of Set 8 | leh
# Processing Record 23 of Set 8 | pangnirtung
# Processing Record 24 of Set 8 | hervey bay
# Processing Record 25 of Set 8 | careiro da varzea
# Processing Record 26 of Set 8 | faya
# Processing Record 27 of Set 8 | guekedou
# City not found. Skipping...
# Processing Record 28 of Set 8 | sorong
# Processing Record 29 of Set 8 | tias
# Processing Record 30 of Set 8 | mount isa
# Processing Record 31 of Set 8 | ucluelet
# Processing Record 32 of Set 8 | codrington
# Processing Record 33 of Set 8 | waingapu
# Processing Record 34 of Set 8 | samarai
# Processing Record 35 of Set 8 | katsuura
# Processing Record 36 of Set 8 | lazaro cardenas
# Processing Record 37 of Set 8 | seddon
# Processing Record 38 of Set 8 | kununurra
# Processing Record 39 of Set 8 | korla
# Processing Record 40 of Set 8 | biu
# Processing Record 41 of Set 8 | the valley
# Processing Record 42 of Set 8 | sitka
# Processing Record 43 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 44 of Set 8 | byron bay
# Processing Record 45 of Set 8 | kargasok
# Processing Record 46 of Set 8 | jieznas
# Processing Record 47 of Set 8 | sinjai
# Processing Record 48 of Set 8 | gros islet
# Processing Record 49 of Set 8 | tukrah
# Processing Record 50 of Set 8 | yuancheng
# Processing Record 1 of Set 9 | chuy
# Processing Record 2 of Set 9 | bagdarin
# Processing Record 3 of Set 9 | cao bang
# Processing Record 4 of Set 9 | kaeo
# Processing Record 5 of Set 9 | la sarre
# Processing Record 6 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 9 | miri
# Processing Record 8 of Set 9 | kimbe
# Processing Record 9 of Set 9 | tromso
# Processing Record 10 of Set 9 | huangzhai
# Processing Record 11 of Set 9 | taos
# Processing Record 12 of Set 9 | sao filipe
# Processing Record 13 of Set 9 | katherine
# Processing Record 14 of Set 9 | saint-augustin
# Processing Record 15 of Set 9 | payson
# Processing Record 16 of Set 9 | chernyshevskiy
# Processing Record 17 of Set 9 | lewiston
# Processing Record 18 of Set 9 | tashara
# Processing Record 19 of Set 9 | bambous virieux
# Processing Record 20 of Set 9 | burnie
# Processing Record 21 of Set 9 | perth
# Processing Record 22 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 9 | hami
# Processing Record 24 of Set 9 | takoradi
# Processing Record 25 of Set 9 | aksu
# Processing Record 26 of Set 9 | vila velha
# Processing Record 27 of Set 9 | daoukro
# Processing Record 28 of Set 9 | bathsheba
# Processing Record 29 of Set 9 | ostrovnoy
# Processing Record 30 of Set 9 | smithers
# Processing Record 31 of Set 9 | nanortalik
# Processing Record 32 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 33 of Set 9 | manta
# Processing Record 34 of Set 9 | kassala
# Processing Record 35 of Set 9 | presidencia roque saenz pena
# Processing Record 36 of Set 9 | clearwater
# Processing Record 37 of Set 9 | castelo do piaui
# Processing Record 38 of Set 9 | opuwo
# Processing Record 39 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 9 | kichera
# Processing Record 41 of Set 9 | santa fe
# Processing Record 42 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 9 | santa cruz de la palma
# Processing Record 44 of Set 9 | souillac
# Processing Record 45 of Set 9 | puerto narino
# Processing Record 46 of Set 9 | rawson
# Processing Record 47 of Set 9 | olafsvik
# Processing Record 48 of Set 9 | paamiut
# Processing Record 49 of Set 9 | tilichiki
# Processing Record 50 of Set 9 | kumylzhenskaya
# Processing Record 1 of Set 10 | margate
# Processing Record 2 of Set 10 | purpe
# Processing Record 3 of Set 10 | leningradskiy
# Processing Record 4 of Set 10 | fortuna
# Processing Record 5 of Set 10 | bay roberts
# Processing Record 6 of Set 10 | linjiang
# Processing Record 7 of Set 10 | murygino
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | lucapa
# Processing Record 10 of Set 10 | micheweni
# Processing Record 11 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 12 of Set 10 | balayong
# Processing Record 13 of Set 10 | natitingou
# Processing Record 14 of Set 10 | vilyuysk
# Processing Record 15 of Set 10 | lulea
# Processing Record 16 of Set 10 | coracao de jesus
# Processing Record 17 of Set 10 | coruripe
# Processing Record 18 of Set 10 | mushie
# Processing Record 19 of Set 10 | alihe
# Processing Record 20 of Set 10 | waddan
# Processing Record 21 of Set 10 | ponta delgada
# Processing Record 22 of Set 10 | khandyga
# Processing Record 23 of Set 10 | adrar
# Processing Record 24 of Set 10 | poladpur
# Processing Record 25 of Set 10 | bestobe
# Processing Record 26 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 27 of Set 10 | svetlyy
# Processing Record 28 of Set 10 | saint-pierre
# Processing Record 29 of Set 10 | mabaruma
# Processing Record 30 of Set 10 | anloga
# Processing Record 31 of Set 10 | mitsamiouli
# Processing Record 32 of Set 10 | iskateley
# Processing Record 33 of Set 10 | nyzhni sirohozy
# Processing Record 34 of Set 10 | karacakoy
# Processing Record 35 of Set 10 | aguimes
# Processing Record 36 of Set 10 | vallenar
# Processing Record 37 of Set 10 | bataipora
# Processing Record 38 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 10 | oksfjord
# Processing Record 40 of Set 10 | nago
# Processing Record 41 of Set 10 | ulaangom
# Processing Record 42 of Set 10 | hay river
# Processing Record 43 of Set 10 | matamoros
# Processing Record 44 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 10 | halifax
# Processing Record 46 of Set 10 | puerto baquerizo moreno
# Processing Record 47 of Set 10 | lagos
# Processing Record 48 of Set 10 | kavieng
# Processing Record 49 of Set 10 | dalbandin
# Processing Record 50 of Set 10 | osoyoos
# Processing Record 1 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 2 of Set 11 | orgun
# City not found. Skipping...
# Processing Record 3 of Set 11 | gat
# Processing Record 4 of Set 11 | juruti
# Processing Record 5 of Set 11 | maraa
# Processing Record 6 of Set 11 | nieuw amsterdam
# Processing Record 7 of Set 11 | saint-denis
# Processing Record 8 of Set 11 | khargupur
# Processing Record 9 of Set 11 | karasuk
# Processing Record 10 of Set 11 | zhangye
# Processing Record 11 of Set 11 | bajitpur
# Processing Record 12 of Set 11 | kudahuvadhoo
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | auki
# Processing Record 15 of Set 11 | sao joao da barra
# Processing Record 16 of Set 11 | kisangani
# Processing Record 17 of Set 11 | abu samrah
# Processing Record 18 of Set 11 | uto
# Processing Record 19 of Set 11 | havre-saint-pierre
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | bowmore
# Processing Record 22 of Set 11 | saint george
# Processing Record 23 of Set 11 | anton lizardo
# Processing Record 24 of Set 11 | rocha
# Processing Record 25 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 11 | laredo
# Processing Record 27 of Set 11 | gisborne
# Processing Record 28 of Set 11 | amazar
# Processing Record 29 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 30 of Set 11 | xique-xique
# Processing Record 31 of Set 11 | elat
# Processing Record 32 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 33 of Set 11 | bangassou
# Processing Record 34 of Set 11 | esperance
# Processing Record 35 of Set 11 | pathein
# Processing Record 36 of Set 11 | bubaque
# Processing Record 37 of Set 11 | losinyy
# Processing Record 38 of Set 11 | vung tau
# Processing Record 39 of Set 11 | la rioja
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | benemerito de las americas
# Processing Record 42 of Set 11 | ust-omchug
# Processing Record 43 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 44 of Set 11 | linxia
# Processing Record 45 of Set 11 | akyab
# Processing Record 46 of Set 11 | neuruppin
# Processing Record 47 of Set 11 | erzin
# Processing Record 48 of Set 11 | cape canaveral
# Processing Record 49 of Set 11 | san cristobal
# Processing Record 50 of Set 11 | walvis bay
# Processing Record 1 of Set 12 | luzhou
# Processing Record 2 of Set 12 | boende
# Processing Record 3 of Set 12 | lingao
# Processing Record 4 of Set 12 | pochutla
# Processing Record 5 of Set 12 | zaragoza
# Processing Record 6 of Set 12 | taywarah
# Processing Record 7 of Set 12 | pimentel
# Processing Record 8 of Set 12 | scottsbluff
# Processing Record 9 of Set 12 | ovsyanka
# Processing Record 10 of Set 12 | kloulklubed
# Processing Record 11 of Set 12 | uthal
# Processing Record 12 of Set 12 | playas
# Processing Record 13 of Set 12 | ternate
# Processing Record 14 of Set 12 | beyneu
# Processing Record 15 of Set 12 | flin flon
# Processing Record 16 of Set 12 | chase
# Processing Record 17 of Set 12 | dickinson
# Processing Record 18 of Set 12 | maniitsoq
# Processing Record 19 of Set 12 | college
# Processing Record 20 of Set 12 | tabou
# Processing Record 21 of Set 12 | nuuk
# Processing Record 22 of Set 12 | mosquera
# Processing Record 23 of Set 12 | namatanai
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | kholodnyy
# Processing Record 26 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 12 | juneau
# Processing Record 28 of Set 12 | razole
# Processing Record 29 of Set 12 | chapais
# Processing Record 30 of Set 12 | leshukonskoye
# Processing Record 31 of Set 12 | bani walid
# Processing Record 32 of Set 12 | manado
# Processing Record 33 of Set 12 | aban
# Processing Record 34 of Set 12 | nouakchott
# Processing Record 35 of Set 12 | guilin
# Processing Record 36 of Set 12 | manggar
# Processing Record 37 of Set 12 | isangel
# Processing Record 38 of Set 12 | zatoka
# Processing Record 39 of Set 12 | biskamzha
# Processing Record 40 of Set 12 | atlantis
# Processing Record 41 of Set 12 | conceicao da barra
# Processing Record 42 of Set 12 | bud
# Processing Record 43 of Set 12 | dong hoi
# Processing Record 44 of Set 12 | svetlaya
# Processing Record 45 of Set 12 | ipinda
# Processing Record 46 of Set 12 | ostersund
# Processing Record 47 of Set 12 | ambulu
# Processing Record 48 of Set 12 | constantine
# Processing Record 49 of Set 12 | muyezerskiy
# Processing Record 50 of Set 12 | tateyama
# Processing Record 1 of Set 13 | constitucion
# Processing Record 2 of Set 13 | haines junction
# Processing Record 3 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 13 | duncan
# Processing Record 5 of Set 13 | arrecife
# Processing Record 6 of Set 13 | delta del tigre
# Processing Record 7 of Set 13 | nantucket
# Processing Record 8 of Set 13 | borba
# Processing Record 9 of Set 13 | broken hill
# Processing Record 10 of Set 13 | ryotsu
# Processing Record 11 of Set 13 | letka
# Processing Record 12 of Set 13 | kamakwie
# Processing Record 13 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 14 of Set 13 | sebinkarahisar
# Processing Record 15 of Set 13 | fonte boa
# Processing Record 16 of Set 13 | honda
# Processing Record 17 of Set 13 | puerto quijarro
# Processing Record 18 of Set 13 | russell
# Processing Record 19 of Set 13 | inhambane
# Processing Record 20 of Set 13 | bria
# Processing Record 21 of Set 13 | saint-leu
# Processing Record 22 of Set 13 | olga
# Processing Record 23 of Set 13 | honiara
# Processing Record 24 of Set 13 | poum
# Processing Record 25 of Set 13 | palmer
# Processing Record 26 of Set 13 | ovalle
# Processing Record 27 of Set 13 | baranain
# Processing Record 28 of Set 13 | okha
# Processing Record 29 of Set 13 | tiznit
# Processing Record 30 of Set 13 | xining
# Processing Record 31 of Set 13 | malpe
# Processing Record 32 of Set 13 | havelock
# Processing Record 33 of Set 13 | monte carmelo
# Processing Record 34 of Set 13 | san jose
# Processing Record 35 of Set 13 | palmetto
# Processing Record 36 of Set 13 | camacha
# Processing Record 37 of Set 13 | upington
# Processing Record 38 of Set 13 | pemangkat
# Processing Record 39 of Set 13 | lashio
# Processing Record 40 of Set 13 | laguna
# Processing Record 41 of Set 13 | pontes e lacerda
# Processing Record 42 of Set 13 | iquique
# Processing Record 43 of Set 13 | singkang
# Processing Record 44 of Set 13 | rauma
# Processing Record 45 of Set 13 | springville
# Processing Record 46 of Set 13 | pervoye maya
# Processing Record 47 of Set 13 | talaya
# Processing Record 48 of Set 13 | nanakuli
# Processing Record 49 of Set 13 | cabedelo
# Processing Record 50 of Set 13 | bridlington
# Processing Record 1 of Set 14 | jalu
# Processing Record 2 of Set 14 | panorama
# Processing Record 3 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 14 | artyom
# Processing Record 5 of Set 14 | hoa binh
# Processing Record 6 of Set 14 | kosmach
# Processing Record 7 of Set 14 | moose factory
# Processing Record 8 of Set 14 | terrace
# Processing Record 9 of Set 14 | tome-acu
# City not found. Skipping...
# Processing Record 10 of Set 14 | moses lake
# Processing Record 11 of Set 14 | vawkavysk
# Processing Record 12 of Set 14 | tandalti
# Processing Record 13 of Set 14 | sechura
# Processing Record 14 of Set 14 | kyenjojo
# Processing Record 15 of Set 14 | rudnaya pristan
# Processing Record 16 of Set 14 | buin
# Processing Record 17 of Set 14 | porto novo
# Processing Record 18 of Set 14 | mancio lima
# Processing Record 19 of Set 14 | lima
# Processing Record 20 of Set 14 | damghan
# Processing Record 21 of Set 14 | vestmanna
# Processing Record 22 of Set 14 | povenets
# Processing Record 23 of Set 14 | karaton
# Processing Record 24 of Set 14 | santacruz
# Processing Record 25 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 14 | vanavara
# Processing Record 27 of Set 14 | baykit
# Processing Record 28 of Set 14 | biloli
# Processing Record 29 of Set 14 | nemuro
# Processing Record 30 of Set 14 | key largo
# Processing Record 31 of Set 14 | billings
# Processing Record 32 of Set 14 | terney
# Processing Record 33 of Set 14 | raudeberg
# Processing Record 34 of Set 14 | abensberg
# Processing Record 35 of Set 14 | shambu
# Processing Record 36 of Set 14 | mlonggo
# Processing Record 37 of Set 14 | madera
# Processing Record 38 of Set 14 | papar
# Processing Record 39 of Set 14 | weligama
# Processing Record 40 of Set 14 | tarakan
# Processing Record 41 of Set 14 | lebork
# Processing Record 42 of Set 14 | havoysund
# Processing Record 43 of Set 14 | luderitz
# Processing Record 44 of Set 14 | baiyin
# Processing Record 45 of Set 14 | nikolayevsk-na-amure
# Processing Record 46 of Set 14 | ust-kulom
# Processing Record 47 of Set 14 | al
# City not found. Skipping...
# Processing Record 48 of Set 14 | riyadh
# Processing Record 49 of Set 14 | severnoye
# Processing Record 50 of Set 14 | turayf
# Processing Record 1 of Set 15 | chardara
# Processing Record 2 of Set 15 | ust-ishim
# Processing Record 3 of Set 15 | alta floresta
# Processing Record 4 of Set 15 | tripoli
# Processing Record 5 of Set 15 | kandrian
# Processing Record 6 of Set 15 | oneida
# Processing Record 7 of Set 15 | christchurch
# Processing Record 8 of Set 15 | rio cuarto
# Processing Record 9 of Set 15 | makasar
# Processing Record 10 of Set 15 | lodja
# Processing Record 11 of Set 15 | san quintin
# Processing Record 12 of Set 15 | galveston
# Processing Record 13 of Set 15 | kirkwood
# Processing Record 14 of Set 15 | sydney mines
# Processing Record 15 of Set 15 | brazzaville
# Processing Record 16 of Set 15 | nangong
# Processing Record 17 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 15 | villa constitucion
# Processing Record 19 of Set 15 | kovernino
# Processing Record 20 of Set 15 | kolodeznyy
# Processing Record 21 of Set 15 | kailua
# Processing Record 22 of Set 15 | mityana
# Processing Record 23 of Set 15 | imbituba
# Processing Record 24 of Set 15 | emirdag
# Processing Record 25 of Set 15 | massaguet
# Processing Record 26 of Set 15 | poshekhonye
# Processing Record 27 of Set 15 | beidao
# Processing Record 28 of Set 15 | saint-michel-des-saints
# Processing Record 29 of Set 15 | fatick
# Processing Record 30 of Set 15 | mount pleasant
# Processing Record 31 of Set 15 | belfast
# Processing Record 32 of Set 15 | kolo
# Processing Record 33 of Set 15 | zaysan
# Processing Record 34 of Set 15 | bull savanna
# Processing Record 35 of Set 15 | milledgeville
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bluff      NZ -46.6000  168.3333     76.80        65          32
# 1      Busselton      AU -33.6500  115.3333     68.04        54           0
# 2         Lompoc      US  34.6391 -120.4579     59.38        68           1
# 3        Alcaniz      ES  41.0500   -0.1333     40.42        87           9
# 4         Albany      US  42.6001  -73.9662     36.52        93         100
# 5        Skhisma      GR  35.2667   25.7167     51.69        74         100
# 6     Bredasdorp      ZA -34.5322   20.0403     62.28        88          75
# 7   Norman Wells      CA  65.2820 -126.8329     -3.96        77          90
# 8  Swift Current      CA  50.2834 -107.8014     14.81        67          75
# 9      Carnarvon      AU -24.8667  113.6333     75.27        50           0
#
#    Wind Speed Current Description
# 0       13.53    scattered clouds
# 1        3.94           clear sky
# 2        9.22           clear sky
# 3        1.90           clear sky
# 4        4.00          light snow
# 5       31.99     overcast clouds
# 6        8.05       broken clouds
# 7        5.75          light snow
# 8       21.85       broken clouds
# 9       19.57           clear sky

# %%
# Create the output file (CSV).
output_data_file = "../Weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df.info
# Out:
# <bound method DataFrame.info of               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     76.80        65          32
# 1        Busselton      AU -33.6500  115.3333     68.04        54           0
# 2           Lompoc      US  34.6391 -120.4579     59.38        68           1
# 3          Alcaniz      ES  41.0500   -0.1333     40.42        87           9
# 4           Albany      US  42.6001  -73.9662     36.52        93         100
# ..             ...     ...      ...       ...       ...       ...         ...
# 676        Belfast      GB  54.5833   -5.9333     45.12        99          90
# 677           Kolo      PL  52.2002   18.6387     40.87        91         100
# 678         Zaysan      KZ  47.4667   84.8667      9.41        76          95
# 679   Bull Savanna      JM  17.8868  -77.5902     74.25        81          48
# 680  Milledgeville      US  33.0801  -83.2321     68.77        96         100
#
#      Wind Speed   Current Description
# 0         13.53      scattered clouds
# 1          3.94             clear sky
# 2          9.22             clear sky
# 3          1.90             clear sky
# 4          4.00            light snow
# ..          ...                   ...
# 676        3.44                  mist
# 677       16.62       overcast clouds
# 678        2.48       overcast clouds
# 679       11.10      scattered clouds
# 680        5.35  heavy intensity rain
#
# [681 rows x 9 columns]>
